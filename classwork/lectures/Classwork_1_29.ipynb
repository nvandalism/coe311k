# %% [markdown]
# Hello Python! This is my very first notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %%
print("Any String!")
# Out:
# Any String!

# %%
print(5)
# Out:
# 5

# %%
print(2+2)
# Out:
# 4

# %%
print(True)
# Out:
# True

# %%
print("Hello Class!")
print("TACC'S awesome")
# Out:
# Hello Class!
# TACC'S awesome

# %%
2+5
# Out:
# 7

# %%
6.7+3.3
# Out:
# 10.0

# %%
name = "Derek"
Name = "John"

# %%
print(name)
print(Name)
# Out:
# Derek
# John

# %%
num67 = 2

# %%
string1 = str(5)

# %%
print(string1)
# Out:
# 5

# %%
print(type(string1))
# Out:
# <class 'str'>

# %%
numIn =  input("put a numbah in")
# Out:
# put a numbah in9

# %%
myfile = open("classwork1_29.dat", 'w')
myfile.write(numIn)
myfile.write("\n")
myfile.write("HelloWorld")
myfile.write("\n")
myfile.close()

# %%
myfile2 = open("classwork1_29.dat", 'r')
content = myfile2.read()
myfile.close()
print(content)
# Out:
# 9
# HelloWorld

# %%
for x in range(0, 3):
    print("Let's go %d" % x)
# Out:
# Let's go 0
# Let's go 1
# Let's go 2

# %%
import random

def approximatePi(numShots):
    counter = 0
    for i in range(0, numShots):
        x = random.uniform(-1, 1)
        y = random.uniform(-1, 1)
        
        if (x*x + y*y < 1):
            counter += 1
    
    return 4.0 * counter / numShots

print(approximatePi(5000000))
# Out:
# 3.1424336

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(0, 2*np.pi, 50)

# %%
plt.plot(x, np.sin(x), x, np.sin(x)**2)
plt.show()

# %%
plt.subplot(2, 1, 1)
plt.plot(x)

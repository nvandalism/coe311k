# %%
import numpy as np
import time
def jacobi(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = np.zeros_like(x)
        for i in range(n):
            s = sum(A[i][j] * x[j] for j in range(n) if j != i)
            x_new[i] = (b[i] - s) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
import numpy as np
def gauss_seidel(A, b, x0, tol, max_iterations):
    n = len(b)
    x = x0.copy()
    for k in range(max_iterations):
        x_new = x.copy()
        for i in range(n):
            s1 = sum(A[i][j] * x_new[j] for j in range(i)) # Using already updated values
            s2 = sum(A[i][j] * x[j] for j in range(i + 1, n)) # Using old values
            x_new[i] = (b[i] - s1 - s2) / A[i][i]
        # Check for convergence
        if np.linalg.norm(x_new - x, ord=np.inf) < tol:
            return x_new, k
        x = x_new
    return x, max_iterations

# %%
A = np.array([[0.582745, 0.48 , 0.10 , 0.  , 0.  ],
[0.48 , 1.044129, 0.46 , 0.10 , 0.  ],
[0.10 , 0.46 , 1.10431 , 0.44 , 0.10 ],
[0.  , 0.10 , 0.44 , 0.963889, 0.42 ],
[0.  , 0.  , 0.10 , 0.42 , 0.522565]], dtype=float)
b = np.array([1.162745, 2.084129, 2.20431 , 1.923889, 1.042565], dtype=float)
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
start = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end = time.perf_counter()
total = end - start
print(f"J Solution: {solution}")
print(f"J Iterations: {iterations}")
print(f"J Operation Time: {total:.6e} seconds")
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.perf_counter()
total = end - start
print(f"GS Solution: {solution}")
print(f"GS Iterations: {iterations}")
print(f"GS Operation Time: {total:.6e} seconds")
# Out:
# J Solution: [0.34253948 0.34219824 0.34215212 0.34233398 0.34277892]
# J Iterations: 100
# J Operation Time: 5.654188e-03 seconds
# GS Solution: [0.99999926 1.00000045 0.99999989 0.99999997 1.00000005]
# GS Iterations: 20
# GS Operation Time: 7.636199e-03 seconds

# %%
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
start = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end = time.perf_counter()
total = end - start
print(f"J Solution: {solution}")
print(f"J Iterations: {iterations}")
print(f"J Operation Time: {total:.6e} seconds")
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.perf_counter()
total = end - start
print(f"GS Solution: {solution}")
print(f"GS Iterations: {iterations}")
print(f"GS Operation Time: {total:.6e} seconds")
# Out:
# J Solution: [1 0]
# J Iterations: 1
# J Operation Time: 5.414337e-04 seconds
# GS Solution: [1 0]
# GS Iterations: 1
# GS Operation Time: 1.387026e-03 seconds

# %%
A = np.array([[1, 1], [1, 1.0001]])
b = np.array([1, 1.0001])
x0 = np.zeros_like(b)
tol = 1e-6
max_iterations = 100
start = time.perf_counter()
solution, iterations = jacobi(A, b, x0, tol, max_iterations)
end = time.perf_counter()
total = end - start
print(f"J Solution: {solution}")
print(f"J Iterations: {iterations}")
print(f"J Operation Time: {total:.6e} seconds")
solution, iterations = gauss_seidel(A, b, x0, tol, max_iterations)
end = time.perf_counter()
total = end - start
print(f"GS Solution: {solution}")
print(f"GS Iterations: {iterations}")
print(f"GS Operation Time: {total:.6e} seconds")
# Out:
# J Solution: [0.         0.00498727]
# J Iterations: 100
# J Operation Time: 4.248366e-03 seconds
# GS Solution: [0.99014933 0.00994967]
# GS Iterations: 100
# GS Operation Time: 1.077273e-02 seconds
